# %% [markdown]
# # 1.Define a class with a generator which can iterate the numbers, which are divisible by
# 7, between a given range 0 and n.
#
# ANSWER-

# %%
class div_generator:
    def __init__(self,n):
        self.n=n
    def get_numbers(self):
        for i in range(0,self.n+1):
            if i%7==0:
                yield i
num=int(input("enter the number of your range "))            
output=div_generator(num)
for i in output.get_numbers():
    print(i,end=' ')
# Out:
# enter the number of your range 400
# 0 7 14 21 28 35 42 49 56 63 70 77 84 91 98 105 112 119 126 133 140 147 154 161 168 175 182 189 196 203 210 217 224 231 238 245 252 259 266 273 280 287 294 301 308 315 322 329 336 343 350 357 364 371 378 385 392 399

# %% [markdown]
# # 2.Write a program to compute the frequency of the words from the input. The output
# should output after sorting the key alphanumerically.
# Suppose the following input is supplied to the program:
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or
# Python 3.
# Then, the output should be:
# 2:2
# 3.:1
# 3?:1
# New:1
# Python:5
# Read:1
# and:1
# between:1
# choosing:1
# or:2
# to:1
#
# ANSWER-

# %%
def checkfrequency():
    string=input("enter the string: ")
    frequency={}
    for i in string.split(" "):
        if frequency.get(i)==None:
            frequency[i]=1
        else:    
            frequency[i]+=1
    for i in sorted(frequency):
        print(f'{i}:{frequency[i]}',end=" ")
        
checkfrequency()
# Out:
# enter the string:  New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3
# :1 2:2 3:1 3?:1 New:1 Python:5 Read:1 and:1 between:1 choosing:1 or:2 to:1

# %% [markdown]
# # 3.Define a class Person and its two child classes: Male and Female. All classes have a method "getGender" which can print "Male" for Male class and "Female" for Female class.
#
# ANSWER-

# %%
class person():
    def getGender():
        pass
    
class Male(person):
    def getGender():
        print("Male")
        
class Female(person):
    def getGender():
        print("Female")
        
Male.getGender()
Female.getGender()
# Out:
# Male
# Female

# %% [markdown]
# # 4.Please write a program to generate all sentences where subject is in ["I","You"] and verb is in ["Play", "Love"] and the object is in ["Hockey","Football"].
#
# ANSWER-

# %%
def generate_sentences():
    subject=["I","You"]
    verb=["Play","Love"]
    object=["Hockey","Football"]
    for i in subject:
        for j in verb:
            for k in object:
                print(f'{i} {j} {k}')
                
generate_sentences()
# Out:
# I Play Hockey
# I Play Football
# I Love Hockey
# I Love Football
# You Play Hockey
# You Play Football
# You Love Hockey
# You Love Football

# %% [markdown]
# # 5.Please write a program to compress and decompress the string "hello world!hello world!hello world!hello world!".
#
# ANSWER-

# %%
def compress(in_string):
    output=in_string[0]
    count=1
    for i in range(len(in_string)-1):
        if in_string[i]==in_string[i+1]:
            count+=1
        else:
            if count>1:
                output+=str(count)
            output+=in_string[i+1]
            count=1
    if count<1:
        output+=str(count)
    print(output)
    
def decompress(in_string):
    output=''
    for i in  range(len(in_string)):
        if in_string[i].isdigit():
            output+=output[-1]*(int(in_string[i])-1)
        else:
            output+=in_string[i]
    print(output)
    
compress("hello world!hello world!hello world!hello world!")
decompress("hello world!hello world!hello world!hello world!")
# Out:
# hel2o world!hel2o world!hel2o world!hel2o world!
# hello world!hello world!hello world!hello world!

# %% [markdown]
# # 6.Please write a binary search function which searches an item in a sorted list. The function should return the index of element to be searched in the list.
#
# ANSWER-

# %%
sorted_list=sorted([9,6,3,4,70,1,4,6,3])
def binarySearch(in_list,in_num):
    low=0
    high=len(in_list)-1
    while low<=high:
        mid=high+low//2
        if in_list[mid]<in_num:
            low=mid+1
        elif in_list[mid]>in_num:
            high=mid-1
        else:
            return mid
    else:
        return "Input list is not in the list"
print("the sorted list is",sorted_list)    
print(binarySearch(sorted_list,70))
print(binarySearch(sorted_list,20))
# Out:
# the sorted list is [1, 3, 3, 4, 4, 6, 6, 9, 70]
# 8
# Input list is not in the list
